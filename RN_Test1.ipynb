# %% [markdown]
# <a href="https://colab.research.google.com/github/giondo/RN-test1/blob/main/RN_Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

# %%
#We prepare the training Data

# the four different states of the XOR gate
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")

# the four expected results in the same order
target_data = np.array([[0],[1],[1],[0]], "float32")

# %%
#We generate and compile the model
model = Sequential()
model.add(Dense(4, input_dim=2, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy'])
#model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(training_data, target_data, epochs=1000, verbose=2, shuffle=True)
# Out:
# Epoch 1/1000
# 1/1 - 1s - loss: 0.2840 - binary_accuracy: 0.7500 - 661ms/epoch - 661ms/step
# Epoch 2/1000
# 1/1 - 0s - loss: 0.2837 - binary_accuracy: 0.5000 - 8ms/epoch - 8ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 0.2833 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 4/1000
# 1/1 - 0s - loss: 0.2830 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 0.2827 - binary_accuracy: 0.7500 - 7ms/epoch - 7ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 0.2823 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 0.2820 - binary_accuracy: 0.7500 - 10ms/epoch - 10ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 0.2817 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 9/1000
# 1/1 - 0s - loss: 0.2813 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 10/1000
# 1/1 - 0s - loss: 0.2810 - binary_accuracy: 0.7500 - 9ms/epoch - 9ms/step
# Epoch 11/1000
# 1/1 - 0s - loss: 0.2806 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# ...

# %%
model.test_on_batch(training_data, target_data)
model.metrics_names

print ("Training data inpur: \n ",training_data )
print ("Target data output:\n ",target_data)
print ("Prediccion del Modelo \n ", model.predict(training_data))#.round()

print(history.history.keys())

#plt.ylabel('accuracy')
plt.xlabel('epoch')

# "Loss"
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.show()
# Out:
# Training data inpur:
#   [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Target data output:
#   [[0.]
#  [1.]
#  [1.]
#  [0.]]
# 1/1 [==============================] - 0s 131ms/step
# Prediccion del Modelo
#   [[0.30268008]
#  [0.71569425]
#  [0.8211413 ]
#  [0.3027607 ]]
# dict_keys(['loss', 'binary_accuracy'])
